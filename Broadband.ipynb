# %% [markdown]
# <a href="https://colab.research.google.com/github/bikram33206/Advanced-house-price-prediction/blob/master/Broadband.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Broadband Outage Detection**

# %% [markdown]
# #**EDA on Broadband Outage Detection**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #**Importing Libraries**

# %%
import pandas as pd

# %% [markdown]
# #**Reading Dataset**

# %%
train_data=pd.read_csv('/content/train_data.csv')
train_data.head(2)
# Out:
#       id area_code  outage_duration
# 0  13366  area_415                1
# 1   6783  area_474                0

# %%
broadband_data=pd.read_csv('/content/broadband_data.csv')
broadband_data.head(2)
# Out:
#      id    broadband_type
# 0  6597  broadband_type_8
# 1  8011  broadband_type_8

# %%
outage_data=pd.read_csv('/content/outage_data.csv')
outage_data.head(2)
# Out:
#      id    outage_type
# 0  6597  outage_type_2
# 1  8011  outage_type_2

# %%
report_data=pd.read_csv('/content/report_data.csv')
report_data.head(2)
# Out:
#      id     log_report_type  volume
# 0  6597  log_report_type_68       6
# 1  8011  log_report_type_68       7

# %%
server_data=pd.read_csv('/content/server_data.csv')
server_data.head(2)
# Out:
#      id     transit_server_type
# 0  6597  transit_server_type_11
# 1  8011  transit_server_type_15

# %% [markdown]
# #**Joining all CSV file train_data, broadband_data,outage_data, report_data, server_datain one DataFrame**

# %%
from functools import reduce
dfs = [train_data,broadband_data,outage_data,report_data,server_data]

# %%
df_final = reduce(lambda left,right: pd.merge(left,right,on='id'), dfs)

# %%
df_final.head()
# Out:
#       id area_code  ...  volume     transit_server_type
# 0  13366  area_415  ...       1  transit_server_type_35
# 1   6783  area_474  ...       2  transit_server_type_35
# 2   6783  area_474  ...       2  transit_server_type_34
# 3   6783  area_474  ...       1  transit_server_type_35
# 4   6783  area_474  ...       1  transit_server_type_34
#
# [5 rows x 8 columns]

# %%
df_final.shape
# Out:
# (48973, 8)

# %% [markdown]
# #**Data PreProcessing**

# %% [markdown]
# # Checking all unique values in Datafrme

# %%
print(df_final.outage_type.unique())
print(len((df_final.outage_type.unique()))) # unique number of Outage _type count
# Out:
# ['outage_type_4' 'outage_type_2' 'outage_type_1' 'outage_type_5'
#  'outage_type_3']
# 5

# %%
print(df_final.area_code.unique())
print(len(df_final.area_code.unique())) # unique number of Area_code count
# Out:
# ['area_415' 'area_474' 'area_931' 'area_700' 'area_600' 'area_645'
#  'area_576' 'area_734' 'area_326' 'area_923' 'area_122' 'area_358'
#  'area_471' 'area_470' 'area_282' 'area_445' 'area_962' 'area_793'
#  'area_846' 'area_468' 'area_476' 'area_737' 'area_467' 'area_1086'
#  'area_1015' 'area_945' 'area_619' 'area_373' 'area_485' 'area_625'
#  'area_172' 'area_976' 'area_320' 'area_704' 'area_794' 'area_805'
#  'area_769' 'area_880' 'area_519' 'area_393' 'area_460' 'area_124'
#  'area_1042' 'area_466' 'area_440' 'area_695' 'area_821' 'area_906'
#  'area_506' 'area_808' 'area_249' 'area_272' 'area_429' 'area_1010'
#  'area_1107' 'area_653' 'area_497' 'area_648' 'area_118' 'area_831'
#  'area_1024' 'area_870' 'area_883' 'area_834' 'area_760' 'area_944'
#  'area_1018' 'area_527' 'area_7' 'area_803' 'area_187' 'area_380'
#  'area_1090' 'area_488' 'area_496' 'area_1084' 'area_995' 'area_627'
#  'area_161' 'area_895' 'area_699' 'area_126' 'area_852' 'area_1033'
#  'area_465' 'area_268' 'area_1056' 'area_451' 'area_570' 'area_1007'
#  'area_797' 'area_974' 'area_344' 'area_388' 'area_73' 'area_837'
#  'area_455' 'area_778' 'area_773' 'area_81' 'area_450' 'area_662'
#  'area_222' 'area_461' 'area_457' 'area_886' 'area_459' 'area_1006'
#  'area_836' 'area_298' 'area_13' 'area_375' 'area_696' 'area_1054'
#  'area_1089' 'area_980' 'area_684' 'area_135' 'area_973' 'area_240'
#  'area_692' 'area_499' 'area_851' 'area_825' 'area_244' 'area_477'
#  'area_9' 'area_967' 'area_444' 'area_1103' 'area_278' 'area_478'
#  'area_665' 'area_742' 'area_599' 'area_1031' 'area_691' 'area_879'
#  'area_963' 'area_257' 'area_1' 'area_313' 'area_763' 'area_179'
#  'area_864' 'area_915' 'area_892' 'area_644' 'area_446' 'area_826'
#  'area_239' 'area_810' 'area_481' 'area_809' 'area_1060' 'area_815'
#  'area_1063' 'area_494' 'area_878' 'area_421' 'area_802' 'area_184'
#  'area_1022' 'area_173' 'area_408' 'area_1061' 'area_638' 'area_202'
#  'area_1116' 'area_206' 'area_229' 'area_891' 'area_744' 'area_661'
#  'area_95' 'area_830' 'area_242' 'area_489' 'area_290' 'area_919'
#  'area_584' 'area_44' 'area_286' 'area_518' 'area_560' 'area_107'
#  'area_641' 'area_885' 'area_102' 'area_829' 'area_960' 'area_324'
#  'area_292' 'area_145' 'area_1035' 'area_283' 'area_128' 'area_1119'
#  'area_888' 'area_672' 'area_814' 'area_195' 'area_1095' 'area_250'
#  'area_1111' 'area_1117' 'area_484' 'area_504' 'area_92' 'area_288'
#  'area_1066' 'area_541' 'area_894' 'area_91' 'area_475' 'area_210'
#  'area_376' 'area_925' 'area_284' 'area_893' 'area_495' 'area_961'
#  'area_604' 'area_932' 'area_921' 'area_1109' 'area_1078' 'area_507'
#  'area_276' 'area_822' 'area_640' 'area_1097' 'area_1093' 'area_909'
#  'area_50' 'area_1045' 'area_609' 'area_434' 'area_448' 'area_270'
#  'area_315' 'area_613' 'area_157' 'area_255' 'area_955' 'area_818'
#  'area_472' 'area_342' 'area_1026' 'area_712' 'area_167' 'area_994'
#  'area_1083' 'area_1052' 'area_155' 'area_39' 'area_389' 'area_999'
#  'area_800' 'area_116' 'area_1079' 'area_1055' 'area_363' 'area_643'
#  'area_856' 'area_897' 'area_498' 'area_84' 'area_601' 'area_355'
#  'area_90' 'area_881' 'area_1072' 'area_949' 'area_754' 'area_323'
#  'area_1100' 'area_1019' 'area_441' 'area_226' 'area_752' 'area_549'
#  'area_230' 'area_1067' 'area_248' 'area_1088' 'area_707' 'area_262'
#  'area_97' 'area_223' 'area_942' 'area_723' 'area_714' 'area_943'
#  'area_1120' 'area_381' 'area_443' 'area_410' 'area_536' 'area_543'
#  'area_984' 'area_243' 'area_957' 'area_639' 'area_505' 'area_469'
#  'area_300' 'area_694' 'area_1023' 'area_426' 'area_583' 'area_977'
#  'area_480' 'area_322' 'area_917' 'area_1038' 'area_755' 'area_1112'
#  'area_151' 'area_57' 'area_898' 'area_369' 'area_558' 'area_806'
#  'area_946' 'area_1099' 'area_664' 'area_618' 'area_147' 'area_1121'
#  'area_642' 'area_181' 'area_353' 'area_533' 'area_414' 'area_311'
#  'area_857' 'area_23' 'area_386' 'area_264' 'area_169' 'area_149'
#  'area_1014' 'area_442' 'area_74' 'area_127' 'area_1096' 'area_224'
#  'area_17' 'area_566' 'area_314' 'area_103' 'area_1058' 'area_823'
#  'area_790' 'area_1008' 'area_998' 'area_603' 'area_939' 'area_362'
#  'area_252' 'area_674' 'area_798' 'area_34' 'area_479' 'area_816'
#  'area_114' 'area_509' 'area_839' 'area_682' 'area_72' 'area_726'
#  'area_845' 'area_1030' 'area_402' 'area_686' 'area_1101' 'area_667'
#  'area_896' 'area_12' 'area_350' 'area_877' 'area_693' 'area_391'
#  'area_817' 'area_950' 'area_968' 'area_602' 'area_1029' 'area_655'
#  'area_93' 'area_890' 'area_16' 'area_849' 'area_651' 'area_204'
#  'area_938' 'area_371' 'area_616' 'area_876' 'area_875' 'area_1044'
#  'area_483' 'area_1081' 'area_348' 'area_8' 'area_159' 'area_1000'
#  'area_735' 'area_866' 'area_280' 'area_447' 'area_577' 'area_347'
#  'area_659' 'area_1098' 'area_420' 'area_1053' 'area_88' 'area_19'
#  'area_1076' 'area_47' 'area_1049' 'area_795' 'area_194' 'area_865'
#  'area_123' 'area_759' 'area_277' 'area_1051' 'area_608' 'area_1082'
#  'area_756' 'area_740' 'area_679' 'area_721' 'area_148' 'area_400'
#  'area_117' 'area_1087' 'area_1077' 'area_418' 'area_256' 'area_490'
#  'area_152' 'area_59' 'area_437' 'area_309' 'area_281' 'area_120'
#  'area_884' 'area_141' 'area_757' 'area_732' 'area_782' 'area_211'
#  'area_532' 'area_767' 'area_328' 'area_540' 'area_690' 'area_205'
#  'area_356' 'area_899' 'area_1002' 'area_329' 'area_296' 'area_745'
#  'area_299' 'area_903' 'area_596' 'area_702' 'area_848' 'area_716'
#  'area_133' 'area_491' 'area_709' 'area_89' 'area_670' 'area_1068'
#  'area_520' 'area_537' 'area_1106' 'area_378' 'area_360' 'area_251'
#  'area_100' 'area_916' 'area_607' 'area_654' 'area_697' 'area_1075'
#  'area_430' 'area_948' 'area_1071' 'area_597' 'area_56' 'area_401'
#  'area_1094' 'area_139' 'area_611' 'area_297' 'area_535' 'area_208'
#  'area_765' 'area_130' 'area_546' 'area_234' 'area_319' 'area_853'
#  'area_186' 'area_493' 'area_1110' 'area_889' 'area_768' 'area_464'
#  'area_705' 'area_346' 'area_1069' 'area_657' 'area_501' 'area_1025'
#  'area_165' 'area_675' 'area_1074' 'area_718' 'area_978' 'area_258'
#  'area_937' 'area_136' 'area_1034' 'area_649' 'area_683' 'area_1115'
#  'area_453' 'area_492' 'area_325' 'area_76' 'area_850' 'area_812'
#  'area_934' 'area_867' 'area_409' 'area_522' 'area_964' 'area_332'
#  'area_500' 'area_615' 'area_1104' 'area_514' 'area_1032' 'area_637'
#  'area_407' 'area_526' 'area_1011' 'area_534' 'area_125' 'area_137'
#  'area_427' 'area_1062' 'area_424' 'area_245' 'area_462' 'area_1017'
#  'area_237' 'area_1048' 'area_413' 'area_49' 'area_33' 'area_930'
#  'area_835' 'area_563' 'area_771' 'area_989' 'area_303' 'area_330'
#  'area_1036' 'area_220' 'area_1108' 'area_511' 'area_370' 'area_947'
#  'area_143' 'area_153' 'area_588' 'area_841' 'area_811' 'area_26'
#  'area_788' 'area_399' 'area_524' 'area_842' 'area_869' 'area_392'
#  'area_180' 'area_548' 'area_914' 'area_911' 'area_687' 'area_746'
#  'area_523' 'area_663' 'area_334' 'area_736' 'area_789' 'area_595'
#  'area_78' 'area_65' 'area_1027' 'area_722' 'area_241' 'area_487'
#  'area_436' 'area_958' 'area_617' 'area_860' 'area_904' 'area_379'
#  'area_621' 'area_956' 'area_785' 'area_113' 'area_269' 'area_1064']
# 876

# %%
print(df_final.outage_duration.unique())
print(len(df_final.outage_duration.unique())) # unique number of Outage_duration count
# Out:
# [1 0 2]
# 3

# %%
print(df_final.broadband_type.unique())
print(len(df_final.broadband_type.unique()))  # unique number of broadband_type count
# Out:
# ['broadband_type_2' 'broadband_type_8' 'broadband_type_4'
#  'broadband_type_7' 'broadband_type_6' 'broadband_type_1'
#  'broadband_type_10' 'broadband_type_3' 'broadband_type_9'
#  'broadband_type_5']
# 10

# %%
print(df_final.outage_type.unique())
print(len(df_final.outage_type.unique()))   # unique number of Outage_type count
# Out:
# ['outage_type_4' 'outage_type_2' 'outage_type_1' 'outage_type_5'
#  'outage_type_3']
# 5

# %%
print(df_final.log_report_type.unique())
print(len(df_final.log_report_type.unique()))  # unique number of log_report_type count
# Out:
# ['log_report_type_312' 'log_report_type_233' 'log_report_type_232'
#  'log_report_type_315' 'log_report_type_235' 'log_report_type_313'
#  'log_report_type_203' 'log_report_type_82' 'log_report_type_80'
#  'log_report_type_54' 'log_report_type_284' 'log_report_type_285'
#  'log_report_type_84' 'log_report_type_55' 'log_report_type_71'
#  'log_report_type_74' 'log_report_type_196' 'log_report_type_195'
#  'log_report_type_309' 'log_report_type_307' 'log_report_type_308'
#  'log_report_type_219' 'log_report_type_134' 'log_report_type_301'
#  'log_report_type_201' 'log_report_type_73' 'log_report_type_227'
#  'log_report_type_229' 'log_report_type_234' 'log_report_type_314'
#  'log_report_type_42' 'log_report_type_157' 'log_report_type_170'
#  'log_report_type_202' 'log_report_type_81' 'log_report_type_171'
#  'log_report_type_163' 'log_report_type_47' 'log_report_type_53'
#  'log_report_type_191' 'log_report_type_70' 'log_report_type_193'
#  'log_report_type_56' 'log_report_type_172' 'log_report_type_94'
#  'log_report_type_135' 'log_report_type_160' 'log_report_type_44'
#  'log_report_type_68' 'log_report_type_362' 'log_report_type_109'
#  'log_report_type_345' 'log_report_type_223' 'log_report_type_306'
#  'log_report_type_86' 'log_report_type_182' 'log_report_type_207'
#  'log_report_type_62' 'log_report_type_118' 'log_report_type_147'
#  'log_report_type_30' 'log_report_type_146' 'log_report_type_273'
#  'log_report_type_148' 'log_report_type_211' 'log_report_type_76'
#  'log_report_type_222' 'log_report_type_75' 'log_report_type_305'
#  'log_report_type_197' 'log_report_type_375' 'log_report_type_291'
#  'log_report_type_283' 'log_report_type_376' 'log_report_type_368'
#  'log_report_type_290' 'log_report_type_331' 'log_report_type_251'
#  'log_report_type_239' 'log_report_type_318' 'log_report_type_209'
#  'log_report_type_87' 'log_report_type_354' 'log_report_type_353'
#  'log_report_type_278' 'log_report_type_277' 'log_report_type_150'
#  'log_report_type_39' 'log_report_type_35' 'log_report_type_127'
#  'log_report_type_154' 'log_report_type_212' 'log_report_type_230'
#  'log_report_type_240' 'log_report_type_153' 'log_report_type_218'
#  'log_report_type_132' 'log_report_type_133' 'log_report_type_83'
#  'log_report_type_204' 'log_report_type_316' 'log_report_type_187'
#  'log_report_type_65' 'log_report_type_189' 'log_report_type_67'
#  'log_report_type_95' 'log_report_type_221' 'log_report_type_78'
#  'log_report_type_199' 'log_report_type_310' 'log_report_type_228'
#  'log_report_type_311' 'log_report_type_236' 'log_report_type_322'
#  'log_report_type_141' 'log_report_type_317' 'log_report_type_8'
#  'log_report_type_25' 'log_report_type_111' 'log_report_type_103'
#  'log_report_type_237' 'log_report_type_29' 'log_report_type_117'
#  'log_report_type_181' 'log_report_type_198' 'log_report_type_61'
#  'log_report_type_167' 'log_report_type_101' 'log_report_type_51'
#  'log_report_type_360' 'log_report_type_179' 'log_report_type_293'
#  'log_report_type_378' 'log_report_type_365' 'log_report_type_79'
#  'log_report_type_200' 'log_report_type_304' 'log_report_type_369'
#  'log_report_type_370' 'log_report_type_85' 'log_report_type_48'
#  'log_report_type_303' 'log_report_type_226' 'log_report_type_279'
#  'log_report_type_108' 'log_report_type_280' 'log_report_type_220'
#  'log_report_type_374' 'log_report_type_289' 'log_report_type_262'
#  'log_report_type_152' 'log_report_type_37' 'log_report_type_276'
#  'log_report_type_349' 'log_report_type_105' 'log_report_type_120'
#  'log_report_type_125' 'log_report_type_122' 'log_report_type_231'
#  'log_report_type_217' 'log_report_type_161' 'log_report_type_41'
#  'log_report_type_156' 'log_report_type_27' 'log_report_type_28'
#  'log_report_type_115' 'log_report_type_114' 'log_report_type_52'
#  'log_report_type_168' 'log_report_type_357' 'log_report_type_358'
#  'log_report_type_38' 'log_report_type_367' 'log_report_type_288'
#  'log_report_type_206' 'log_report_type_205' 'log_report_type_190'
#  'log_report_type_224' 'log_report_type_137' 'log_report_type_2'
#  'log_report_type_20' 'log_report_type_178' 'log_report_type_10'
#  'log_report_type_267' 'log_report_type_341' 'log_report_type_266'
#  'log_report_type_112' 'log_report_type_377' 'log_report_type_292'
#  'log_report_type_330' 'log_report_type_320' 'log_report_type_241'
#  'log_report_type_238' 'log_report_type_50' 'log_report_type_63'
#  'log_report_type_361' 'log_report_type_359' 'log_report_type_225'
#  'log_report_type_57' 'log_report_type_173' 'log_report_type_45'
#  'log_report_type_66' 'log_report_type_188' 'log_report_type_145'
#  'log_report_type_96' 'log_report_type_16' 'log_report_type_46'
#  'log_report_type_15' 'log_report_type_33' 'log_report_type_149'
#  'log_report_type_274' 'log_report_type_347' 'log_report_type_255'
#  'log_report_type_333' 'log_report_type_250' 'log_report_type_213'
#  'log_report_type_128' 'log_report_type_384' 'log_report_type_299'
#  'log_report_type_268' 'log_report_type_155' 'log_report_type_248'
#  'log_report_type_183' 'log_report_type_162' 'log_report_type_192'
#  'log_report_type_175' 'log_report_type_40' 'log_report_type_180'
#  'log_report_type_1' 'log_report_type_136' 'log_report_type_77'
#  'log_report_type_177' 'log_report_type_169' 'log_report_type_140'
#  'log_report_type_98' 'log_report_type_164' 'log_report_type_165'
#  'log_report_type_49' 'log_report_type_18' 'log_report_type_69'
#  'log_report_type_383' 'log_report_type_298' 'log_report_type_60'
#  'log_report_type_249' 'log_report_type_329' 'log_report_type_380'
#  'log_report_type_295' 'log_report_type_24' 'log_report_type_11'
#  'log_report_type_43' 'log_report_type_139' 'log_report_type_158'
#  'log_report_type_176' 'log_report_type_59' 'log_report_type_26'
#  'log_report_type_113' 'log_report_type_104' 'log_report_type_194'
#  'log_report_type_245' 'log_report_type_325' 'log_report_type_210'
#  'log_report_type_348' 'log_report_type_275' 'log_report_type_58'
#  'log_report_type_166' 'log_report_type_339' 'log_report_type_332'
#  'log_report_type_319' 'log_report_type_143' 'log_report_type_142'
#  'log_report_type_5' 'log_report_type_159' 'log_report_type_124'
#  'log_report_type_107' 'log_report_type_208' 'log_report_type_186'
#  'log_report_type_257' 'log_report_type_335' 'log_report_type_338'
#  'log_report_type_261' 'log_report_type_337' 'log_report_type_259'
#  'log_report_type_247' 'log_report_type_302' 'log_report_type_334'
#  'log_report_type_256' 'log_report_type_144' 'log_report_type_9'
#  'log_report_type_253' 'log_report_type_99' 'log_report_type_17'
#  'log_report_type_336' 'log_report_type_258' 'log_report_type_110'
#  'log_report_type_215' 'log_report_type_216' 'log_report_type_363'
#  'log_report_type_131' 'log_report_type_130' 'log_report_type_106'
#  'log_report_type_7' 'log_report_type_366' 'log_report_type_364'
#  'log_report_type_242' 'log_report_type_371' 'log_report_type_123'
#  'log_report_type_244' 'log_report_type_260' 'log_report_type_328'
#  'log_report_type_21']
# 310

# %%
print(df_final.volume.unique())
print(len(df_final.volume.unique()))   # unique number of volume count
# Out:
# [  1   2   3   6  30  14 273 270   8  34   4  21  66  65   5  16  18  23
#   25  10  28   7  13  12  69  67  17  40  24 108 104   9  35  29  22  11
#   19  20  32  57  15  42 176 168  45  39  41  76 114  83  27  26  37 186
#   47  43  36  48 151 132  53  46 156 171  50  38  68  74  89  31  44  85
#   88 107 143  55  59  52 100 144  90 413  62  61  33 207 237  58  49 185
#  190  63  71  82  96  81  70  79  75  94 120  51  78  60  64  54  93 213
#  211 240  72 101  84  56 293  99 164 122  91 111 155 109  86 346 349 263
#  212  97 175 148 158 255 258 129 434 105 283 189 118 102 180 166 159 154
#  128  87  92 153 323 300 234 170 188  95 647 574 235 334 138 229 265 312
#  364 195 149 632 145 119 228 230 127 110  98 335 115 226 131 150 152  73
#  167 146 248 179 177 877 662 112 137 187 135 140 126 271 116 103 133 124
#  192 125 191 588 450 200 117 139 134 214 233 172  80 121 183 267 113 163
#  326 441 203 123 106 206 296 141 451 354 205 202 209 320 157 208 288 636
#  301 173  77 162 239 251]
# 240

# %%
print(df_final.transit_server_type.unique())
print(len(df_final.transit_server_type.unique())) # unique number of transit_server_type count
# Out:
# ['transit_server_type_35' 'transit_server_type_34'
#  'transit_server_type_15' 'transit_server_type_11'
#  'transit_server_type_46' 'transit_server_type_47'
#  'transit_server_type_20' 'transit_server_type_14'
#  'transit_server_type_21' 'transit_server_type_54'
#  'transit_server_type_23' 'transit_server_type_13' 'transit_server_type_6'
#  'transit_server_type_22' 'transit_server_type_44'
#  'transit_server_type_42' 'transit_server_type_43'
#  'transit_server_type_18' 'transit_server_type_24'
#  'transit_server_type_10' 'transit_server_type_28'
#  'transit_server_type_27' 'transit_server_type_30'
#  'transit_server_type_29' 'transit_server_type_5' 'transit_server_type_38'
#  'transit_server_type_36' 'transit_server_type_45'
#  'transit_server_type_40' 'transit_server_type_37'
#  'transit_server_type_31' 'transit_server_type_32'
#  'transit_server_type_50' 'transit_server_type_26' 'transit_server_type_7'
#  'transit_server_type_49' 'transit_server_type_53' 'transit_server_type_2'
#  'transit_server_type_51' 'transit_server_type_9' 'transit_server_type_8'
#  'transit_server_type_1' 'transit_server_type_3' 'transit_server_type_19'
#  'transit_server_type_39' 'transit_server_type_41'
#  'transit_server_type_12' 'transit_server_type_25'
#  'transit_server_type_48']
# 49

# %% [markdown]
# #**Checking Null values**

# %%
df_final.isnull().sum() #We are seing that there is no null values present in our dataset
# Out:
# id                     0
# area_code              0
# outage_duration        0
# broadband_type         0
# outage_type            0
# log_report_type        0
# volume                 0
# transit_server_type    0
# dtype: int64

# %% [markdown]
# # **EDA**

# %%
import numpy as np
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt

x = df_final.outage_duration
num_bins = 5
n, bins, patches = plt.hist(x, num_bins, facecolor='blue', alpha=0.5)
plt.show()

# %%
import numpy as np
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt
x=df_final.volume
num_bins = 5
n, bins, patches = plt.hist(x, num_bins, facecolor='blue', alpha=0.5)
plt.show()

# %%
# list of numerical variables
numerical_features = [feature for feature in df_final.columns if df_final[feature].dtypes != 'O']

print('Number of numerical variables: ', len(numerical_features))

# visualise the numerical variables
df_final[numerical_features].head()
# Out:
# Number of numerical variables:  3
#       id  outage_duration  volume
# 0  13366                1       1
# 1   6783                0       2
# 2   6783                0       2
# 3   6783                0       1
# 4   6783                0       1

# %%
categorical_features=[feature for feature in df_final.columns if df_final[feature].dtypes=='O']
categorical_features
# Out:
# ['area_code',
#  'broadband_type',
#  'outage_type',
#  'log_report_type',
#  'transit_server_type']

# %%
df_final[categorical_features].head()
# Out:
#   area_code    broadband_type  ...      log_report_type     transit_server_type
# 0  area_415  broadband_type_2  ...  log_report_type_312  transit_server_type_35
# 1  area_474  broadband_type_2  ...  log_report_type_312  transit_server_type_35
# 2  area_474  broadband_type_2  ...  log_report_type_312  transit_server_type_34
# 3  area_474  broadband_type_2  ...  log_report_type_233  transit_server_type_35
# 4  area_474  broadband_type_2  ...  log_report_type_233  transit_server_type_34
#
# [5 rows x 5 columns]

# %%
for feature in categorical_features:
    print('The feature is {} and number of categories are {}'.format(feature,len(df_final[feature].unique())))
# Out:
# The feature is area_code and number of categories are 876
# The feature is broadband_type and number of categories are 10
# The feature is outage_type and number of categories are 5
# The feature is log_report_type and number of categories are 310
# The feature is transit_server_type and number of categories are 49

# %%
import plotly.express as px
grouping = df_final[df_final['outage_duration']==2].groupby('area_code')['id'].count().reset_index()


fig = px.line(grouping, x='area_code', y="id", 
              title="Outage_duration counts over area where outage_duration=2(Maximum Outage duration)")

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="f2fef237-5969-411b-bb5c-cf07cc36fb1f" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("f2fef237-5969-411b-bb5c-cf07cc36fb1f")) {
#                     Plotly.newPlot(
#                         'f2fef237-5969-411b-bb5c-cf07cc36fb1f',
#                         [{"hoverlabel": {"namelength": 0}, "hovertemplate": "area_code=%{x}<br>id=%{y}", "legendgroup": "", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "", "showlegend": false, "type": "scatter", "x": 
70, 3, 73, 29, 2, 64, 12, 59, 7, 2, 1, 243, 108, 240, 16, 3, 8, 5, 490, 300, 96, 2, 54, 2, 54, 3, 2, 3, 10, 10, 16, 2, 16, 93, 12, 1, 74, 1, 8, 20, 90, 24, 60, 8, 76, 16, 20, 152, 24, 85, 64, 4, 5, 97, 2, 9, 121, 10, 2, 10, 64, 338, 56, 69, 133, 3, 43, 16, 3, 2, 8, 9, 160, 35, 130, 128, 313, 4, 11, 68, 16, 3, 6, 37, 30, 1, 112, 10, 18, 5, 1, 4, 5, 93, 18, 18, 182, 159, 18, 4, 38, 2, 28, 96, 34, 26, 168, 8, 6, 2, 52, 42, 4, 4, 39, 256, 2, 12, 166, 1], "yaxis": "y"}],
#                         {"legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolargl"}], "scatterterna ...

# %%
fig = plt.figure(figsize=(5,5), dpi=200)
ax = plt.subplot(111)

df_final[df_final['outage_duration']==2].area_code.value_counts().plot(kind='pie', ax=ax, autopct='%1.1f%%', startangle=270, fontsize=5)

# %%
import plotly.express as px
grouping = df_final[df_final['outage_duration']==2].groupby('broadband_type')['id'].count().reset_index()


fig = px.scatter(grouping, x='broadband_type', y="id",
              title='Outage_duration counts over broadband type where outage_duration=2(Maximum Outage duration)')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="4735c942-e093-4efe-80f9-45e5d702c007" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("4735c942-e093-4efe-80f9-45e5d702c007")) {
#                     Plotly.newPlot(
#                         '4735c942-e093-4efe-80f9-45e5d702c007',
#                         [{"hoverlabel": {"namelength": 0}, "hovertemplate": "broadband_type=%{x}<br>id=%{y}", "legendgroup": "", "marker": {"color": "#636efa", "symbol": "circle"}, "mode": "markers", "name": "", "showlegend": false, "type": "scatter", "x": ["broadband_type_1", "broadband_type_10", "broadband_type_2", "broadband_type_3", "broadband_type_4", "broadband_type_5", "broadband_type_6", "broadband_type_7", "broadband_type_8", "broadband_type_9"], "xaxis": "x", "y": [253, 70, 1456, 126, 364, 110, 498, 306, 3533, 98], "yaxis": "y"}],
#                         {"legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolargl"}], "scatterterna ...

# %%
import plotly.express as px
grouping = df_final[df_final['outage_duration']==2].groupby('broadband_type')['id'].count().reset_index()


fig = px.bar(grouping, x='broadband_type', y="id",
              title='Outage_duration counts over broadband type where outage_duration=2(Maximum Outage duration)')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="85cc59bc-3b56-48a0-bb83-5f60880c3750" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("85cc59bc-3b56-48a0-bb83-5f60880c3750")) {
#                     Plotly.newPlot(
#                         '85cc59bc-3b56-48a0-bb83-5f60880c3750',
#                         [{"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "broadband_type=%{x}<br>id=%{y}", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": ["broadband_type_1", "broadband_type_10", "broadband_type_2", "broadband_type_3", "broadband_type_4", "broadband_type_5", "broadband_type_6", "broadband_type_7", "broadband_type_8", "broadband_type_9"], "xaxis": "x", "y": [253, 70, 1456, 126, 364, 110, 498, 306, 3533, 98], "yaxis": "y"}],
#                         {"barmode": "relative", "legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpo ...

# %%
import plotly.express as px
grouping = df_final[df_final['outage_duration']==2].groupby('broadband_type')['id'].count().reset_index()


fig = px.line(grouping, x='broadband_type', y="id",
              title='Outage_duration counts over broadband type where outage_duration=2(Maximum Outage duration)')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="d6abd1ab-9f63-40d5-8e81-50106660a641" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("d6abd1ab-9f63-40d5-8e81-50106660a641")) {
#                     Plotly.newPlot(
#                         'd6abd1ab-9f63-40d5-8e81-50106660a641',
#                         [{"hoverlabel": {"namelength": 0}, "hovertemplate": "broadband_type=%{x}<br>id=%{y}", "legendgroup": "", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "", "showlegend": false, "type": "scatter", "x": ["broadband_type_1", "broadband_type_10", "broadband_type_2", "broadband_type_3", "broadband_type_4", "broadband_type_5", "broadband_type_6", "broadband_type_7", "broadband_type_8", "broadband_type_9"], "xaxis": "x", "y": [253, 70, 1456, 126, 364, 110, 498, 306, 3533, 98], "yaxis": "y"}],
#                         {"legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolargl"}], "scatterterna ...

# %%
fig = plt.figure(figsize=(5,5), dpi=200)
ax = plt.subplot(111)

df_final[df_final['outage_duration']==2].broadband_type.value_counts().plot(kind='pie', ax=ax, autopct='%1.1f%%', startangle=270, fontsize=5)
